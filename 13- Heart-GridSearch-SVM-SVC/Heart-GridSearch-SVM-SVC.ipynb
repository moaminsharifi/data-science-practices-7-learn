# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC

# %%
data = pd.read_csv('heart.csv')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
X = data.iloc[:, :-1].values
y = data.iloc[:, 13].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                     'C': [1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000]}]

scores = ['precision', 'recall']

for score in scores:
    print("# Score: %s" % score)
    print()

    clf = GridSearchCV(SVC(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print()
    print(clf.best_params_)
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Score: precision
#
#
# {'C': 1, 'kernel': 'linear'}
#
# 0.632 (+/-0.106) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.691 (+/-0.133) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.625 (+/-0.064) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.692 (+/-0.089) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.609 (+/-0.079) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.751 (+/-0.129) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.599 (+/-0.089) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.760 (+/-0.138) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.838 (+/-0.060) for {'C': 1, 'kernel': 'linear'}
# 0.825 (+/-0.102) for {'C': 10, 'kernel': 'linear'}
# 0.835 (+/-0.148) for {'C': 100, 'kernel': 'linear'}
# 0.827 (+/-0.067) for {'C': 1000, 'kernel': 'linear'}
#
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.73      0.79        44
#            1       0.78      0.89      0.83        47
#
#     accuracy                           0.81        91
#    macro avg       0.82      0.81      0.81        91
# weighted avg       0.82      0.81      0.81        91
#
#
# # Score: recall
#
#
# {'C': 1, 'kernel': 'linear'}
#
# 0.628 (+/-0.111) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.661 (+/-0.113) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.625 (+/-0.066) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.676 (+/-0.086) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.608 (+/-0.079) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.732 (+/-0.137) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.598 (+/-0.088) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.754 (+/-0.147) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.828 (+/-0.049) for {'C': 1, 'kernel': 'linear'}
# 0.806 (+/-0.081) for {'C': 10, 'kernel': 'linear'}
# 0.822 (+/-0.138) for {'C': 100, 'kernel': 'linear'}
# 0.816 (+/-0.078) for {'C': 1000, 'kernel': 'linear'}
#
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.73      0.79        44
#            1       0.78      0.89      0.83        47
#
#     accuracy                           0.81        91
#    macro avg       0.82      0.81      0.81        91
# weighted avg       0.82      0.81      0.81        91
